# %%
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
import numpy as np
from sklearn.metrics import mean_squared_error, mean_absolute_error, r2_score, root_mean_squared_error
from model import build_lstm_model
from preprocessing import parse_start_time, convert_to_datetime, create_sequence

# %% [markdown]
# # RUL Prediction
# - Data: Discharge cycle of a battery (B0005)
# - Description: Use the first 50 cycles of discharge data to predict the next cycles
# - Model: LSTM & GRU

# %%
discharge_dataset = pd.read_csv("../../dataset/processed/discharge_data.csv")

discharge_data = discharge_dataset[discharge_dataset["battery_id"] == "B0005"].copy()

# %% [markdown]
# ### Discharge capacity fade over cycles

# %%
plt.figure(figsize=(10, 5))
plt.plot(discharge_data["cycle_number"], discharge_data["Capacity"], marker="o", linestyle="-", color="b")

plt.xlabel("Cycle Number")
plt.ylabel("Discharge Capacity")
plt.title("Battery B0005: Capacity Degradation Over Cycles")
plt.grid(True)

plt.show()

# %% [markdown]
# ## Feature Engineering

# %% [markdown]
# ### Convert datetime to delta_t between cycles

# %%
discharge_data["start_time"] = discharge_data["start_time"].apply(parse_start_time)

discharge_data["datetime"] = discharge_data["start_time"].apply(convert_to_datetime)

discharge_data["delta_time"] = (discharge_data["datetime"] - discharge_data["datetime"].iloc[0]).dt.total_seconds()

# %%
data = discharge_data[["delta_time", "Capacity", "cycle_number"]].copy()

# %%
features = ["delta_time", "cycle_number"]
target = "Capacity"

# %% [markdown]
# ### Scaler

# %%
# from sklearn.preprocessing import MinMaxScaler

# scaler_X = MinMaxScaler()
# scaler_y = MinMaxScaler()

# X_scaled = scaler_X.fit_transform(data[features])
# y_scaled = scaler_y.fit_transform(data[[target]])

# X, y = np.array(X_scaled), np.array(y_scaled)

# %% [markdown]
# ## Build model

# %%
sequence_length = 50

X, y = create_sequence(
# Out:
# (118, 50, 2) (118, 1)

# %% [markdown]
# ### LSTM

# %%
input_dim = X.shape[1]

model = build_lstm_model(sequence_length, input_dim)
# Out:
# 2
# c:\Users\HLC\AppData\Local\Programs\Python\Python311\Lib\site-packages\keras\src\layers\rnn\rnn.py:204: UserWarning: Do not pass an `input_shape`/`input_dim` argument to a layer. When using Sequential models, prefer using an `Input(shape)` object as the first layer in the model instead.
#   super().__init__(**kwargs)

# %%
model.fit(X_train, y_train, epochs=50, batch_size=16, verbose=1)
# Out:
# Epoch 1/50
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 3s 26ms/step - loss: 0.1339
# Epoch 2/50
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 0s 28ms/step - loss: 0.0869
# Epoch 3/50
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 0s 28ms/step - loss: 0.0629
# Epoch 4/50
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 0s 30ms/step - loss: 0.0369
# Epoch 5/50
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 0s 27ms/step - loss: 0.0060
# Epoch 6/50
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 0s 31ms/step - loss: 0.0044
# Epoch 7/50
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 0s 30ms/step - loss: 0.0020
# Epoch 8/50
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 0s 25ms/step - loss: 0.0018
# Epoch 9/50
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 0s 31ms/step - loss: 0.0018
# Epoch 10/50
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 0s 24ms/step - loss: 0.0017
# Epoch 11/50
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 0s 26ms/step - loss: 0.0014
# Epoch 12/50
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 0s 29ms/step - loss: 0.0013
# Epoch 13/50
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 0s 28ms/step - loss: 0.0013
# Epoch 14/50
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 0s 28ms/step - loss: 0.0012
# Epoch 15/50
# ...

# %%
predictions = []
input_seq = X[0:sequence_length]

for i in range(50, len(X)):  # Predict from cycle 51 to the end
    input_seq_reshaped = input_seq.reshape(1, sequence_length, X.shape[1])

    next_capacity = model.predict(input_seq_reshaped)
    next_capacity = scaler_y.inverse_transform(next_capacity.reshape(-1, 1))[0][0]

    predictions.append(next_capacity)

    new_input = np.append(input_seq[1:], [X[i]], axis=0)
    input_seq = new_input

# %%
actual_values = scaler_y.inverse_transform(y[50:])

mae = mean_absolute_error(actual_values, predictions)
r2 = r2_score(actual_values, predictions)
rmse = root_mean_squared_error(actual_values, predictions)

print(f"RMSE: {rmse:.4f}")
print(f"MAE: {mae:.4f}")
print(f"R^2: {r2:.4f}")

# %%
plt.figure(figsize=(10, 5))
plt.plot(range(51, len(y) + 1), actual_values, marker="o", label="Actual Capacity")
plt.plot(range(51, len(y) + 1), predictions, marker="x", linestyle="dashed", color="red", label="Predicted Capacity")
plt.xlabel("Cycle Number")
plt.ylabel("Capacity")
plt.legend()
plt.title(f"Actual vs LSTM Prediction from Cycle 51")
plt.show()

# %%
model.save("lstm_01.h5")

# %% [markdown]
# # Test on other batteries

# %%
test_data = discharge_dataset[discharge_dataset["battery_id"] == "B0006"].copy()

test_data["start_time"] = test_data["start_time"].apply(parse_start_time)
test_data["datetime"] = test_data["start_time"].apply(convert_to_datetime)
test_data["delta_time"] = (test_data["datetime"] - test_data["datetime"].iloc[0]).dt.total_seconds()

test_data = test_data[["delta_time", "Capacity", "cycle_number"]].copy()

# %%
plt.figure(figsize=(10, 5))
plt.plot(test_data["cycle_number"], test_data["Capacity"], marker="o", linestyle="-", color="b")

plt.xlabel("Cycle Number")
plt.ylabel("Discharge Capacity")
plt.title("Battery B0005: Capacity Degradation Over Cycles")
plt.grid(True)

plt.show()

# %%
X = scaler_X.transform(test_data[["delta_time", "cycle_number"]])
y = scaler_y.transform(test_data[["Capacity"]])

X, y = np.array(X), np.array(y)

# %%
X_test_seq = X[:sequence_length]

# %%
predictions = []
for i in range(50, len(X)):
    X_test_seq_reshaped = X_test_seq.reshape(1, sequence_length, X.shape[1])

    next_capacity_scaled = model.predict(X_test_seq_reshaped)
    next_capacity = scaler_y.inverse_transform(next_capacity_scaled.reshape(-1, 1))[0][0]

    predictions.append(next_capacity)

    new_input = np.append(X_test_seq[1:], [X[i]], axis=0)
    X_test_seq = new_input

# %%
from sklearn.metrics import mean_squared_error, mean_absolute_error, r2_score, root_mean_squared_error

actual_values = scaler_y.inverse_transform(y[50:])


mae = mean_absolute_error(actual_values, predictions)
r2 = r2_score(actual_values, predictions)
rmse = root_mean_squared_error(actual_values, predictions)

print(f"RMSE: {rmse:.4f}")
print(f"MAE: {mae:.4f}")
print(f"R^2: {r2:.4f}")

# %%
plt.figure(figsize=(10, 5))
plt.plot(range(51, 51 + len(predictions)), actual_values, label="Actual Capacity", marker='o', linestyle='-')
plt.plot(range(51, 51 + len(predictions)), predictions, label="Predicted Capacity", marker='s', linestyle='--')

plt.xlabel("Cycle Number")
plt.ylabel("Capacity")
plt.title(f"Battery B0006: Actual vs Predicted Capacity\nMAE: {mae:.4f}, RMSE: {rmse:.4f}")
plt.legend()
plt.grid()
plt.show()
